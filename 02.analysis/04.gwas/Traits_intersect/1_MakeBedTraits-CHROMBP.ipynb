# %%
# Load Packages
pacman::p_load(parallel, R.utils, remotes,
               ggplot2, ggrepel,
               dplyr, tidyr, data.table, stringr, scales)

# When playing with chromosomes it's always good to avoid scientific annotation
options(scipen = 999)

# %% [markdown]
# # Make Bed Traits

# %%
# Setup directories
traits.dir = "/nfs/lab/FinnGen_R11/finemap/summary/"
traits.bed.dir = '/nfs/lab/tscc/luca/MEGA_Heart/Finrich/Inputs/chromBP_input/'

traits.meta.path = "/nfs/lab/projects/mega_heart/FNIH/multiome/Analysis/3_downstream/Major_celltypes/LDSC/TRAITS_pub.meta.txt"

# %%
# Grep all traits
files = dir(traits.dir, pattern = ".SUSIE.snp.filter.tsv")
files = files[!grepl(pattern = ".tbi", x = files)]
files = data.frame(files = paste0(traits.dir, files), 
           trait = str_split_fixed(files, ".SUSIE.snp.filter.tsv", n = 2)[,1])

message("all traits found: ", nrow(files))
# Out:
# all traits found: 1250

# %%
# Load traits we car about
traits.meta = fread(traits.meta.path, header = TRUE)
colnames(traits.meta)[2] = "Internal_Study_ID"

traits.meta = traits.meta %>%
        dplyr::filter(Internal_Study_ID == "finngen") %>%
        left_join(files, by = "trait")

# %%
# DOING THIS HERE, PREPARING A METADATA FOR KYLE
traits.meta = fread("/nfs/lab/projects/mega_heart/Assets/Traits_metadatada.txt")

files$trait = gsub(pattern = "finngen_R11_",
                 replacement = "",
                 x = files$trait)

files$trait = gsub(pattern = "_Hg38",
                 replacement = "",
                 x = files$trait)

# attach better label
files_meta = merge(files, traits.meta, by.x = "trait", by.y = "phenocode")

# %%
files = traits.meta
files = dplyr::filter(files, File != "finngen_R11_I9_MI_COMPLICATIONS") # Random trait I don't have susie for
traits.use = files$Phenotype

# %%
files_meta = dplyr::filter(files_meta, Priority %in% c("CMP", "HF"))

files_meta

write.table(files_meta, 
            "/nfs/lab/projects/mega_heart/Assets/HF_traits_metadatada.txt", 
            col.names = TRUE, row.names = F, sep = "\t", quote = F)
# Out:
#    trait
# 1  FG_CARDMYO
# 2  I9_CARDMYO
# 3  I9_CARDMYOHYP
# 4  I9_CARDMYOOTH
# 5  I9_HEARTFAIL
# 6  I9_HEARTFAIL_ALLCAUSE
# 7  I9_HEARTFAIL_AND_ANTIHYPERT
# 8  I9_HEARTFAIL_AND_CHD
# 9  I9_HEARTFAIL_AND_HYPERTCARDIOM
# 10 I9_HEARTFAIL_AND_OVERWEIGHT
# 11 I9_HEARTFAIL_EXMORE
# 12 I9_IHD
# 13 I9_NONISCHCARDMYOP
# 14 I9_NONISCHCARDMYOP_STRICT
#    files
# 1  /nfs/lab/FinnGen_R11/finemap/summary/finngen_R11_FG_CARDMYO.SUSIE.snp.filter.tsv
# 2  /nfs/lab/FinnGen_R11/finemap/summary/finngen_R11_I9_CARDMYO.SUSIE.snp.filter.tsv
# 3  /nfs/lab/FinnGen_R11/finemap/summary/finngen_R11_I9_CARDMYOHYP.SUSIE.snp.filter.tsv
# 4  /nfs/lab/FinnGen_R11/finemap/summary/finngen_R11_I9_CARDMYOOTH.SUSIE.snp.filter.tsv
# 5  /nfs/lab/FinnGen_R11/finemap/summary/finngen_R11_I9_HEARTFAIL.SUSIE.snp.filter.tsv
# 6  /nfs/lab/FinnGen_R11/finemap/summary/finngen_R11_I9_HEARTFAIL_ALLCAUSE.SUSIE.snp.filter.tsv
# 7  /nfs/lab/FinnGen_R11/finemap/summary/finngen_R11_I9_HEARTFAIL_AND_ANTIHYPERT.SUSIE.snp.filter.tsv
# 8  /nfs/lab/FinnGen_R11/finemap/summary/finngen_R11_I9_HEARTFAIL_AND_CHD.SUSIE.snp.filter.tsv
# 9  /nfs/lab/FinnGen_R11/finemap/summary/finngen_R11_I9_HEARTFAIL_AND_HYPERTCARDIOM.SUSIE.snp.filter.tsv
# 10 /nfs/lab/FinnGen_R11/finemap/summary/finngen_R11_I9_HEARTFAIL_AND_OVERWEIGHT.SUSIE.snp.filter.tsv
# 11 /nfs/lab/FinnGen_R11/finemap/summary/finngen_R11_I9_HEARTFAIL_EXMORE.SUSIE.snp.filter.tsv
# 12 /nfs/lab/FinnGen_R11/finemap/summary/finngen_R11_I9_IHD.SUSIE.snp.filter.tsv
# 13 /nfs/lab/FinnGen_R11/finemap/summary/finngen_R11_I9_NONISCHCARDMYOP.SUSIE.snp.filter.tsv
# 14 /nfs/lab/FinnGen_R11/finemap/summary/finngen_R11_I9_NONISCHCARDMYOP_STRICT.SUSIE.snp.filter.tsv
#    phenotype                                       Priority USE
# 1  Cardiomyopathy (excluding other heart disease)  CMP      YES
# 2  Cardiomyopathy                                  CMP      YES
# 3  Cardiomyopathy, Hypertrophic obstructive        CMP      NO
# 4  Cardiomyopathy, other and unspecified           CMP      NO
# 5  Heart failure, strict                           HF       NO
# 6  All-cause Heart Failure                         HF       YES
# 7  Heart failure and antihypertensive medication   HF       YES
# 8  Heart failure and coronary heart disease        HF       YES
# 9  Heart failure and hypertrophic cardiomyopathy   HF       NO
# 10 Heart failure and bmi 25plus                    HF       NO
# 11 Heart failure, strict (more control exclusions) HF       NO
# 12 Ischaemic heart disease, wide definition        CMP      YES
# 13 Non-ischemic cardiomyopathy                     CMP      YES
# 14 Non-ischemic cardiomyopathy (Strict)            CMP      YES
#    category                                    num_cases num_controls
# 1  Cardiometabolic endpoints                    4845     359571
# 2  IX Diseases of the circulatory system (I9_)  6907     342690
# 3  IX Diseases of the circulatory system (I9_)   608     342690
# 4  IX Diseases of the circulatory system (I9_)  2844     342690
# 5  IX Diseases of the circulatory system (I9_) 33250     420483
# 6  IX Diseases of the circulatory system (I9_) 32733     419755
# 7  Cardiometabolic endpoints                   31527     213338
# 8  Cardiometabolic endpoints                   15579     402635
# 9  Cardiometabolic endpoints                     517     452488
# 10 Cardiometabolic endpoints                   20044     182596
# 11 IX Diseases of the circulatory system (I9_) 33250     394758
# 12 IX Diseases of the circulatory system (I9_) 75592     378141
# 13 IX Diseases of the circulatory system (I9_) 12164     365977
# 14 IX Diseases of the circulatory system (I9_)  1911     375549

# %%
# Make bed files
for (i in seq_along(traits.use)){
    # Grep files and make names
    file.use = files$files[i]
    trait.use = files$File[i]
    message("Making a bed for ", trait.use)
    out.bed.file = paste(traits.bed.dir, trait.use, "_Hg38.txt", sep = "")
    # Read table
    trait.data = read.table(file.use, header = TRUE)

    # Manipolate table
    trait.data = trait.data %>%
            dplyr::filter(cs != "-1") %>%
            dplyr::mutate(region = gsub(pattern = ":", replacement = "-", x = region),
                   chr = str_split_fixed(string = region, pattern = "-", n = 3)[,1],
                   start = position - 1,
                   end = position,
                   signal = paste0(region, "--", cs)) %>%
            dplyr::select(chromosome, start, allele1, allele2, cs_specific_prob)
    
    message("Variants found: ", nrow(trait.data))
    
    # Save table
    write.table(trait.data,
                file = out.bed.file,
                col.names = F, row.names = F, sep = "\t", quote = F)
}
# Out:
# Making a bed for finngen_R11_C_STROKE
#
# Variants found: 216
#
# Making a bed for finngen_R11_I9_ANGINA
#
# Variants found: 2232
#
# Making a bed for finngen_R11_I9_ANGIO
#
# Variants found: 1378
#
# Making a bed for finngen_R11_I9_AORTANEUR
#
# Variants found: 1048
#
# Making a bed for finngen_R11_I9_CABG
#
# Variants found: 1300
#
# Making a bed for finngen_R11_I9_CAVS_OPERATED
#
# Variants found: 1041
#
# Making a bed for finngen_R11_I9_CORATHER
#
# Variants found: 2769
#
# Making a bed for finngen_R11_I9_HYPTENS
#
# Variants found: 8658
#
# Making a bed for finngen_R11_I9_HYPTENSESS
#
# Variants found: 7241
#
# Making a bed for finngen_R11_I9_HYPTENSHD
#
# Variants found: 384
#
# Making a bed for finngen_R11_I9_REVASC
#
# Variants found: 2920
#
# Making a bed for finngen_R11_I9_VHD
#
# Variants found: 530
#
# Making a bed for finngen_R11_FG_CVD
#
# Variants found: 2429
#
# Making a bed for finngen_R11_FG_OTHHEART
#
# Variants found: 1196
#
# Making a bed for finngen_R11_I9_CVD_HARD
#
# Variants found: 1318
#
# Making a bed for finngen_R11_I9_HEARTFAIL_AND_ANTIHYPERT
#
# Variants found: 1883
#
# Making a bed for finngen_R11_I9_HEARTFAIL_AND_CHD
#
# Variants found: 713
#
# Making a bed for finngen_R11_CARDIAC_ARRHYTM
#
# Variants found: 2414
#
# Making a bed for finngen_R11_FG_DOAAC
#
# Variants found: 669
#
# Making a bed for finngen_R11_I9_AF
#
# Variants found: 2929
#
# Making a bed for finngen_R11_I9_AF_REIMB
#
# Variants found: 2194
#
# Making a bed for finngen_R11_I9_CARDMYOOTH
#
# Variants found: 70
#
# Making a bed for finngen_R11_I9_CHD
#
# Variants found: 2280
#
# Making a bed for finngen_R11_I9_HEARTFAIL
#
# Variants found: 282
#
# Making a bed for finngen_R11_I9_HEARTFAIL_ALLCAUSE
#
# Variants found: 330
#
# Making a bed for finngen_R11_I9_HEARTFAIL_EXMORE
#
# Variants found: 413
#
# Making a bed for finngen_R11_I9_IHD
#
# Variants found: 2083
#
# Making a bed for finngen_R11_I9_MI_STRICT
#
# Variants found: 1633
#
# Making a bed for finngen_R11_I9_NONISCHCARDMYOP_STRICT
#
# Variants found: 119
#
# Making a bed for finngen_R11_I9_NONRHEVALV
#
# Variants found: 456
#
# Making a bed for finngen_R11_I9_OTHARR
#
# Variants found: 446
